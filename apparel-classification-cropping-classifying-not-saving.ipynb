# %%
import pandas as pd
import os
import tensorflow as tf
import tensorflow_hub as hub
import numpy as np
import cv2
import numpy as np

# %%
apparel_list = ['T-Shirt','Shirt', 'Dress', 'Pants', 'Shorts','Skirt']

# %%
IMG_SIZE = 224

def process_image(image_array,img_size=IMG_SIZE):
    """
    Take an image file path and turn image into a Tensor.
    """
#     image = tf.io.read_file(image_path) # Read image file
#     image = tf.image.decode_jpeg(image,channels=3) # Turn the image into 3 channels RGB
#     image = tf.image.convert_image_dtype(image,tf.float32) # Turn the value 0-255 to 0-1
#     image = tf.image.resize(image,size=[img_size,img_size]) # Resize the image to 224x224
    image = tf.keras.preprocessing.image.array_to_img(roi_list[2], data_format=None, scale=True, dtype=None)
    return image

# %%
BATCH_SIZE = 32

def create_data_batches(X,y=None,batch_size=BATCH_SIZE,valid_data=False,test_data=False):
    """
    Create batches of data out of image (X)
    Also accepts test data as input (no labels).
    """
    if test_data:
        print("Creating testing data batches...")
        data = tf.data.Dataset.from_tensor_slices((tf.constant(X))) # Only file path (no label)
#         print(data)
        print(type(X))
#         data_batch = X.map(process_image).batch(batch_size)
#         return data_batch

# %%
custom_data = create_data_batches(custom_image_paths,test_data=True)
custom_data
# Out:
# Creating testing data batches...
# <TensorSliceDataset shapes: (), types: tf.string>
# <class 'list'>

# %%
custom_data = create_data_batches(roi_list,test_data=True)
custom_data
# Out:
# Creating testing data batches...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-79fe9ae136bf> in <module>
# ----> 1 custom_data = create_data_batches(roi_list,test_data=True)
#       2 custom_data
#
# <ipython-input-44-b9ef9fbaf66b> in create_data_batches(X, y, batch_size, valid_data, test_data)
#       8     if test_data:
#       9         print("Creating testing data batches...")
# ---> 10         data = tf.data.Dataset.from_tensor_slices((tf.constant(X))) # Only file path (no label)
#      11         print(data)
#      12         print(type(X))
#
# ~/Desktop/Personal/env/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     262     ValueError: if called on a symbolic tensor.
#     263   """
# --> 264   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     265                         allow_broadcast=True)
#     266
#
# ~/Desktop/Personal/env/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     274       with trace.Trace("tf.constant"):
#     275         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 276     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     277
#     278   g = ops.get_default_graph()
#
# ~/Desktop/Personal/env/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     299 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     300   """Implementation of eager constant."""
# --> 301   t = convert_to_eager_tensor(value, ctx, dtype)
#     302   if shape is None:
#     303     return t
#
# ~/Desktop/Personal/env/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#      96       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#      97   ctx.ensure_initialized()
# ---> 98   return ops.EagerTensor(value, ctx.device_name, dtype)
#      99
#     100
#
# ValueError: Can't convert non-rectangular Python sequence to Tensor.

# %% [markdown]
# #### 1. Upload the classifier model

# %%
model = tf.keras.models.load_model("models/apparel-classification.h5",custom_objects={'KerasLayer':hub.KerasLayer})

# %% [markdown]
# #### 2. Upload image

# %%
filename = "2"

# %%
from IPython.display import Image

Image(f'images/{filename}.jpg',width=200,height=200)

# %%
img = cv2.imread(f'images/{filename}.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) # convert to grayscale
# threshold to get just the signature (INVERTED)
retval, thresh_gray = cv2.threshold(gray, thresh=100, maxval=255,type=cv2.THRESH_BINARY_INV)
contours, hierarchy = cv2.findContours(thresh_gray,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)
# Find object with the biggest bounding box
ind = 0
roi_list = []
for cont in contours:
    x,y,w,h = cv2.boundingRect(cont)
    if w > 50 and h > 50:
        roi=img[y:y+h,x:x+w]
        ind+=1
        roi_list.append(roi)
        cv2.imwrite(f'cropped/Image_crop{filename}-{ind}.jpg', roi)
        cv2.rectangle(img,(x,y),(x+w,y+h),(200,0,0),2)
cv2.imwrite(f'image_cont/Image_cont{filename}.jpg', img)
# Out:
# True

# %%
test = tf.keras.preprocessing.image.array_to_img(roi_list[2], data_format=None, scale=True, dtype=None)
test
# Out:
# <PIL.Image.Image image mode=RGB size=298x385 at 0x7FD0040A2910>

# %%
custom_preds = model.predict(test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-f5c9f64363c8> in <module>
# ----> 1 custom_preds = model.predict(test)
#
# ~/Desktop/Personal/env/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1596                         '. Consider setting it to AutoShardPolicy.DATA.')
#    1597
# -> 1598       data_handler = data_adapter.DataHandler(
#    1599           x=x,
#    1600           batch_size=batch_size,
#
# ~/Desktop/Personal/env/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution)
#    1097       self._steps_per_execution_value = steps_per_execution.numpy().item()
#    1098
# -> 1099     adapter_cls = select_data_adapter(x, y)
#    1100     self._adapter = adapter_cls(
#    1101         x,
#
# ~/Desktop/Personal/env/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py in select_data_adapter(x, y)
#     959   if not adapter_cls:
#     960     # TODO(scottzhu): This should be a less implementation-specific error.
# --> 961     raise ValueError(
#     962         "Failed to find data adapter that can handle "
#     963         "input: {}, {}".format(
#
# ValueError: Failed to find data adapter that can handle input: <class 'PIL.Image.Image'>, <class 'NoneType'>

# %%
from IPython.display import Image

Image(f'image_cont/Image_cont{filename}.jpg',width=200,height=200)

# %%
type(custom_data)
# Out:
# tensorflow.python.data.ops.dataset_ops.BatchDataset

# %% [markdown]
# #### 4. Predict class of image

# %%
# Test the real images
predicted_list = []
custom_path= "cropped/"
custom_image_paths = [custom_path + fname for fname in os.listdir(custom_path) if fname !=".DS_Store"]
custom_data = create_data_batches(custom_image_paths,test_data=True)
custom_preds = model.predict(custom_data)
for preds in custom_preds:
    temp_list = []
    for i,pred in enumerate(preds,0): 
        temp_list.append([pred,apparel_list[i]])
    predicted_list.append(temp_list)
custom_preds_label = [apparel_list[np.argmax(cp)] for cp in custom_preds]
custom_images = []
for image in custom_data.unbatch().as_numpy_iterator():
    custom_images.append(image)
string_list = []
for preds in predicted_list:
    string = ""
    for pred in sorted(preds,reverse=True):
        string+= pred[1]+f": {pred[0]*100:.2f}%\n"
    string_list.append(string)
plt.figure(figsize=(15, 15))
for i, image in enumerate(custom_images):
    plt.subplot(1, len(custom_preds_label), i+1)
    plt.xticks([])
    plt.yticks([])
    plt.title(custom_preds_label[i])
    plt.text(60,350,s=string_list[i])
    plt.imshow(image)
# Out:
# Creating testing data batches...
# <TensorSliceDataset shapes: (), types: tf.string>
# Tensor("convert_image:0", shape=(None, None, 3), dtype=float32)
